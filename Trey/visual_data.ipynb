# %%
import pandas as pd
from pathlib import Path

# %%
# Import data
joined_path = Path("../Histories/joined_forexdata.csv")

# Read in data and index by DateTime
joined_forexdata = pd.read_csv(joined_path, index_col='DateTime')

# %%
joined_forexdata.Close.plot(figsize= (30,10))

# %%
import matplotlib.pyplot as plt

# %%
for i in range(2, 8):
    x = df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-cdd7715bc866> in <module>
#       1 for i in range(2, 8):
# ----> 2     x = df
#
# NameError: name 'df' is not defined

# %%
800/60
# Out:
# 13.333333333333334
